# %% [markdown]
# # Data Analysis
# ### In this step, we just transform the statistics we get into the DataFrame for further processes.

# %%
from google.colab import drive
drive.mount('/content/drive/')
import os
path="/content/drive/My Drive/Research/Data/"

os.chdir(path)
os.listdir(path)
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).
# ['2019_2020_all_data_final.csv',
#  '2014_abs',
#  '2015_abs',
#  '2016_abs',
#  '2017_abs',
#  '2018_abs',
#  'My_Process',
#  'all_data_statistic.csv',
#  'top_category_details.csv',
#  'top5_statistic_months.csv',
#  'top5_statistics_col.csv']

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re

# %%
data = pd.read_csv(path+'top5_statistic_months.csv')
data = data.T

# %%
data = data.rename(columns={0:'cs',1:'stat',2:'hep_ph',3:'quant_pd',4:'hep_th'})
data
# Out:
#               cs  stat  hep_ph  quant_pd  hep_th
# Unnamed: 0    cs  stat  hep_ph  quant_pd  hep_th
# 2014_Jan    1049   168     273       332     239
# 2014_Feb     806   168     261       303     196
# 2014_Mar     793   151     241       362     248
# 2014_Apr     995   152     252       312     243
# ...          ...   ...     ...       ...     ...
# 2020_Aug    3817  1349     335       632     399
# 2020_Sep    4081  1444     377       755     473
# 2020_Oct    5865  1713     367       700     456
# 2020_Nov    4833  1009     396       656     451
# 2020_Dec     142    54      21        33      24
#
# [85 rows x 5 columns]

# %%
data = data.drop(index=['Unnamed: 0'])
data
# Out:
#             cs  stat hep_ph quant_pd hep_th
# 2014_Jan  1049   168    273      332    239
# 2014_Feb   806   168    261      303    196
# 2014_Mar   793   151    241      362    248
# 2014_Apr   995   152    252      312    243
# 2014_May   998   207    271      323    268
# ...        ...   ...    ...      ...    ...
# 2020_Aug  3817  1349    335      632    399
# 2020_Sep  4081  1444    377      755    473
# 2020_Oct  5865  1713    367      700    456
# 2020_Nov  4833  1009    396      656    451
# 2020_Dec   142    54     21       33     24
#
# [84 rows x 5 columns]

# %%
#data=data.reset_index().rename(columns={'index':'Datetime'})

# %%
data.to_csv(path+'top5_statistics_col_1.csv')
